# %% [markdown]
# ![Banner](docs/Banner.png)

# %% [markdown]
# # Dolphin: InSAR phase linking library for creating surface displacement maps using persistent scatterer (PS) and distributed scatterer (DS) processing
#
# **Author:** Scott Staniewicz, Sara Mirzaee, August 18-22, 2025 [EarthScope InSAR Short Course (ISCE+)](https://www.earthscope.org/event/insar-processing-and-analysis-isce/).
#
# dolphin is an open-source package for InSAR time-series analysis and is the core software used to produce OPERA displacement products. The inputs are stacks of coregistered SLCs (in either geo- or radar-coordinates) in all gdal compatible formats and outputs are displacement time-series without corrections.
#
# dolphin is available on Github from the following page: https://github.com/isce-framework/dolphin
#
# References:
#
# + S. Staniewicz, S. Mirzaee, G. M. Gunter, T. O. Cabrera, E. Havazli, H.Fattahi ., (2024). Dolphin :
# A Python package for large-scale InSAR PS/DS processing. Journal of Open Source Software,
# 9(103), 6997. [ [doi](https://doi.org/10.21105/joss.06997) ]

# %% [markdown]
# # Table of Contents
#
# + [0. Initial setup](#0.-Initial-setup-of-the-notebook)
# + [1. General overview](#1.-General-overview-of-dolphin)
#    - [1.1 Processing steps](#1.1-Processing-steps-of-dolphin)
# + [2. Time series analysis](#2.-Time-series-analysis---Phase-Linking)
# + [3. dolphin subcommnds](#3.-Other-dolphin-commands)

# %% [markdown]
# # 0. Initial setup of the notebook
#
# The cell below performs the intial setup of the notebook and must be **run every time the notebook (re)starts**. It defines the processing location and check the example dataset.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from osgeo import gdal
from itertools import islice
from pathlib import Path

plt.rcParams.update({'font.size': 12})

# define and go to the work directory
work_dir = Path("./").expanduser()
work_dir.mkdir(parents=True, exist_ok=True)

# define the custom config file
src_cfg = Path("dolphin_config.yaml")
config_file = work_dir / src_cfg.name
print("Work directory:", work_dir)


# --- GDAL viewer (accepts str or Path) ---
def view_gdal(file, v_range=None, ref=None, mask=None, bbox=None):
    """
    file: str | Path - raster to view
    v_range: (vmin, vmax) or None
    ref: (row, col) or None - subtract value at this pixel
    mask: str | Path or None - mask raster (nonzero/1 keeps data)
    bbox: (xmin, ymin, xmax, ymax) in pixel indices or None - crop [x0:x1, y0:y1]
    """
    file = Path(file)
    ds = gdal.Open(str(file), gdal.GA_ReadOnly)
    if ds is None:
        raise FileNotFoundError(f"Cannot open raster: {file}")

    data = ds.GetRasterBand(1).ReadAsArray()

    if ref is not None:
        data = data.astype(float, copy=False)
        data -= data[ref[0], ref[1]]

    if mask is not None:
        mask = Path(mask)
        dsmask = gdal.Open(str(mask), gdal.GA_ReadOnly)
        if dsmask is None:
            raise FileNotFoundError(f"Cannot open mask: {mask}")
        mask_array = dsmask.GetRasterBand(1).ReadAsArray()
        data = np.ma.masked_array(data, 1 - mask_array)

    if bbox is not None:
        # bbox = (x0, y0, x1, y1)
        data = data[bbox[1]:bbox[3], bbox[0]:bbox[2]]

    if v_range is None:
        plt.imshow(data, interpolation="none", cmap="RdBu_r")
    else:
        plt.imshow(data, vmin=v_range[0], vmax=v_range[1], interpolation="none", cmap="RdBu_r")
    plt.colorbar()
    plt.show()
# Out:
# Work directory: .

# %%
# download the staged data from AWS 
tar_file = work_dir / 'NewOrleans.tar.gz'
if tar_file.exists():
    print('Staged RSLC data exists at: {}'.format(tar_file))
else:
    # !aws s3 cp s3://earthscope-insar2025/dolphin-isce2/NewOrleans.tar.gz ./


# decompress the tar file [it takes ~1.5 min]
print('decompressing the downloaded dataset...')
# !pv NewOrleans.tar.gz | tar -xz
# Out:
# Staged RSLC data exists at: NewOrleans.tar.gz
# decompressing the downloaded dataset...
# 23.6GiB 0:06:44 [59.9MiB/s] [================================>] 100%

# %% [markdown]
# # 1. General overview of dolphin
#
# This application provides a workflow for phase linking which includes two main steps: creating a config file and running the workflow with the configuration parameters set.
#
# Configuration parameters for each step are initiated with default values in a customizable text file (dolphin_config.yaml). In this notebook, we will walk through the various steps.

# %% [markdown]
# ![flowchart](docs/flowchart.png)
#
# <p style="text-align: center;">
#     (Figure from Scott J. Staniewicz et al., 2024)
# </p>

# %% [markdown]
# ## 1.1 Processing steps of dolphin
#
# Running all subcommands with "--help", shows the full command line.

# %%
# !dolphin --help

# %% [markdown]
# The main subcommands to run the workflow are `config` and `run`. An empty configuration yaml file can be generated with `--print-empty` or by specifying the input coregistered SLCs at minimum.

# %%
# !dolphin config --print-empty
# !dolphin config --cslc ./data/SLC/*/*.tif
yaml_path = Path("dolphin_config.yaml")
for line in islice(yaml_path.open(), 60):  # change 40 as needed
    print(line.rstrip())
# Out:
# input_options:
#   # If passing HDF5/NetCDF files, subdataset to use from CSLC files. .
#   #   Type: string | null.
#   subdataset:
#   # Format of dates contained in CSLC filenames.
#   #   Type: string.
#   cslc_date_fmt: '%Y%m%d'
#   # Radar wavelength (in meters) of the transmitted data. used to convert the units in the
#   #   rasters in `timeseries/` to from radians to meters. If None and sensor is not
#   #   recognized, outputs remain in radians.
#   #   Type: number | null.
#   wavelength: 0.056
# # Mask file used to ignore low correlation/bad data (e.g water mask). Convention is 0 for no
# #   data/invalid, and 1 for good data. Dtype must be uint8.
# #   Type: string | null.
# mask_file:
# # Name of sub-directory to use for writing output files.
# #   Type: string.
# work_directory: ./
# worker_settings:
#   # Whether to use GPU for processing (if available).
#   #   Type: boolean.
#   gpu_enabled: true
#   # Number of threads to use per worker. This sets the OMP_NUM_THREADS environment variable in
#   #   each python process.
#   #   Type: integer.
#   threads_per_worker: 4
#   # If processing separate spatial bursts, number of bursts to run in parallel for wrapped-
#   #   phase-estimation. For large, single-swath SLC stacks (e.g. UAVSAR, NISAR), this sets the
#   #   number of chunks processed in parallel during phase linking.
#   #   Type: integer.
#   n_parallel_bursts: 2
#   # Size (rows, columns) of blocks of data to load at a time.
#   #   Type: array.
#   block_shape:
#     - 512
#     - 512
# # Path to output log file (in addition to logging to `stderr`). Default logs to
# #   `dolphin.log` within `work_directory`.
# #   Type: string | null.
# log_file:
# # REQUIRED: list of CSLC files, or newline-delimited file containing list of CSLC files.
# #   Type: array.
# cslc_file_list: "data/SLC/*/2*.slc.tif"
# output_options:
#   strides:
#     # Decimation factor (stride) in the y/row direction.
#     #   Type: integer.
#     y: 2
#     # Decimation factor (stride) in the x/column direction.
#     #   Type: integer.
#     x: 12
#   # Area of interest: [left, bottom, right, top] coordinates. e.g.
#   #   `bbox=[-150.2,65.0,-150.1,65.5]`.
#   #   Type: array | null.
#   bounds:
#   # EPSG code for the `bounds` or `bounds_wkt` coordinates, if specified.
#   #   Type: integer | null.
#   bounds_epsg: 4326
#   # Area of interest as a simple Polygon in well-known-text (WKT) format. Can pass a string,

# %% [markdown]
# From the config parameters, following are the main parameters you may want to set before running the workflow.
# 1. cslc_file_list
# 2. wavelength  (if you don't set it, output timeseries are in radians unit)
# 3. strides (to generate a lower resolution product by selecting PS and DS pixels wisely in a moving window)
# 4. half_window (for finding statistically homogeneous pixels)
# 5. interferogram_network (generate a network based on your application requirements for unwrapping. set reference_idx for a single reference network, max_bandwidth for a nearest-n network)

# %% [markdown]
# # 2. Time series analysis - Phase Linking
#
# Run the whole workflow from reading input coregistered SLCs to output displacement timeseries and velocity map.
# There is another folder in the input data which refers to corresponding geometry files generated by ISCE2. They are not generally required

# %%
# !dolphin run dolphin_config.yaml
# Out:
# [INFO|displacement|L117] 2025-08-19T21:05:36+0000: Found SLC files from 1 bursts
# [INFO|wrapped_phase|L103] 2025-08-19T21:05:36+0000: Running wrapped phase estimation in /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking
# [WARNING|wrapped_phase|L553] 2025-08-19T21:05:36+0000: Could not make nodata mask: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/data/SLC/20241223/20241223.slc.tif is not a CSLC file
# [INFO|wrapped_phase|L149] 2025-08-19T21:05:36+0000: Creating persistent scatterer file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/PS/ps_pixels.tif
# [INFO|_readers|L1090] 2025-08-19T21:05:36+0000: Processing (512, 512) sized blocks...
# PS (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phas
# [INFO|ps|L159] 2025-08-19T21:11:34+0000: Waiting to write 0 blocks of data.
# [INFO|ps|L162] 2025-08-19T21:11:34+0000: Repacking PS rasters for better compression
# /opt/conda/envs/earthscope_insar/lib/python3.12/site-packages/rasterio/__init__.py:366: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(
# [INFO|ps|L166] 2025-08-19T21:11:40+0000: Finished writing out PS files
# [INFO|ps|L306] 2025-08-19T21:11:40+0000: Saving a looked PS mask to /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/PS/ps_pixels_looked.tif
# [INFO|wrapped_phase|L207] 2025-08-19T21:11:42+0000: Running sequential EMI step in /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase
# [INFO|sequential|L85] 2025-08-19T21:11:42+0000: File range start: 20220108.slc.tif
# [INFO|sequential|L86] 2025-08-19T21:11:42+0000: File range end: 20241223.slc.tif
# [INFO|sequential|L87] 2025-08-19T21:11:42+0000: Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase
# [INFO|sequential|L88] 2025-08-19T21:11:42+0000: Number of ministacks of size 15: 6
# [INFO|sequential|L114] 2025-08-19T21:11:42+0000: Processing 15 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20220108_20220929
# [INFO|single|L89] 2025-08-19T21:11:42+0000: VRTStack(15 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20220108_20220929.vrt): from [datetime.datetime(2022, 1, 8, 0, 0)] to [datetime.datetime(2022, 9, 29, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:11:44+0000: Processing 15 SLCs + 0 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:11:44+0000: Total stack size (in pixels): (15, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:17:17+0000: Waiting to write 35 blocks of data.
# [INFO|single|L378] 2025-08-19T21:17:17+0000: Finished ministack of size (15, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:17:17+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:04,  3.19it/s]
# Processing Rasters:  13%|███▏                    | 2/15 [00:00<00:02,  5.00it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  8.84it/s]
# Processing Rasters:  40%|█████████▌              | 6/15 [00:00<00:01,  8.09it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:01<00:00,  9.60it/s]
# Processing Rasters:  67%|███████████████▎       | 10/15 [00:01<00:00,  7.63it/s]
# Processing Rasters:  73%|████████████████▊      | 11/15 [00:01<00:00,  6.90it/s]
# Processing Rasters:  87%|███████████████████▉   | 13/15 [00:01<00:00,  7.38it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:02<00:00,  7.38it/s]
# [INFO|single|L384] 2025-08-19T21:17:19+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:06<00:43,  6.17s/it]
#  25%|███████████▎                                 | 2/8 [00:10<00:30,  5.07s/it]
#  38%|████████████████▉                            | 3/8 [00:14<00:23,  4.72s/it]
#  50%|██████████████████████▌                      | 4/8 [00:19<00:18,  4.60s/it]
#  62%|████████████████████████████▏                | 5/8 [00:23<00:13,  4.48s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:27<00:08,  4.42s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:30<00:03,  3.90s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:33<00:00,  4.19s/it]
# [INFO|single|L395] 2025-08-19T21:17:53+0000: Repacking CRLB files for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:  13%|███▏                    | 2/15 [00:00<00:01, 11.00it/s]
# Processing Rasters:  27%|██████▍                 | 4/15 [00:00<00:01, 10.38it/s]
# Processing Rasters:  47%|███████████▏            | 7/15 [00:00<00:00,  9.85it/s]
# Processing Rasters:  73%|████████████████▊      | 11/15 [00:01<00:00, 11.23it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:01<00:00, 13.21it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L114] 2025-08-19T21:17:54+0000: Processing 16 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20221011_20230328
# [INFO|single|L89] 2025-08-19T21:17:54+0000: VRTStack(16 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20221011_20230328.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)) to [datetime.datetime(2023, 3, 28, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:17:56+0000: Processing 15 SLCs + 1 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:17:56+0000: Total stack size (in pixels): (16, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:23:38+0000: Waiting to write 35 blocks of data.
# [INFO|single|L378] 2025-08-19T21:23:38+0000: Finished ministack of size (16, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:23:38+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:08,  1.71it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  5.97it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:01<00:00,  7.32it/s]
# Processing Rasters:  67%|███████████████▎       | 10/15 [00:01<00:00,  6.45it/s]
# Processing Rasters:  73%|████████████████▊      | 11/15 [00:01<00:00,  6.91it/s]
# Processing Rasters:  87%|███████████████████▉   | 13/15 [00:02<00:00,  6.80it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:02<00:00,  6.50it/s]
# [INFO|single|L384] 2025-08-19T21:23:40+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:04<00:32,  4.71s/it]
#  25%|███████████▎                                 | 2/8 [00:09<00:27,  4.66s/it]
#  38%|████████████████▉                            | 3/8 [00:13<00:22,  4.47s/it]
#  50%|██████████████████████▌                      | 4/8 [00:17<00:17,  4.39s/it]
#  62%|████████████████████████████▏                | 5/8 [00:22<00:13,  4.37s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:26<00:08,  4.43s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:29<00:03,  3.91s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:32<00:00,  4.05s/it]
# [INFO|single|L395] 2025-08-19T21:24:13+0000: Repacking CRLB files for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:04,  3.33it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  8.93it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:00<00:00, 10.58it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:01<00:00, 12.56it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L114] 2025-08-19T21:24:14+0000: Processing 17 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20230409_20231205
# [INFO|single|L89] 2025-08-19T21:24:14+0000: VRTStack(17 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20230409_20231205.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)) to [datetime.datetime(2023, 12, 5, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:24:17+0000: Processing 15 SLCs + 2 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:24:17+0000: Total stack size (in pixels): (17, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:30:23+0000: Waiting to write 35 blocks of data.
# [INFO|single|L378] 2025-08-19T21:30:23+0000: Finished ministack of size (17, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:30:23+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:07,  1.76it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:01<00:01,  5.65it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:01<00:00,  6.59it/s]
# Processing Rasters:  80%|██████████████████▍    | 12/15 [00:01<00:00,  9.08it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:02<00:00,  6.63it/s]
# [INFO|single|L384] 2025-08-19T21:30:25+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:04<00:33,  4.73s/it]
#  25%|███████████▎                                 | 2/8 [00:09<00:26,  4.50s/it]
#  38%|████████████████▉                            | 3/8 [00:13<00:22,  4.42s/it]
#  50%|██████████████████████▌                      | 4/8 [00:17<00:17,  4.48s/it]
#  62%|████████████████████████████▏                | 5/8 [00:22<00:13,  4.43s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:26<00:08,  4.38s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:29<00:03,  3.88s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:32<00:00,  4.03s/it]
# [INFO|single|L395] 2025-08-19T21:30:58+0000: Repacking CRLB files for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:03,  3.80it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:00, 12.86it/s]
# Processing Rasters:  47%|███████████▏            | 7/15 [00:00<00:00, 10.34it/s]
# Processing Rasters:  67%|███████████████▎       | 10/15 [00:01<00:00,  9.93it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:01<00:00, 12.36it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L114] 2025-08-19T21:30:59+0000: Processing 18 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20231217_20240602
# [INFO|single|L89] 2025-08-19T21:30:59+0000: VRTStack(18 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20231217_20240602.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)) to [datetime.datetime(2024, 6, 2, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:31:01+0000: Processing 15 SLCs + 3 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:31:01+0000: Total stack size (in pixels): (18, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:37:37+0000: Waiting to write 35 blocks of data.
# [INFO|single|L378] 2025-08-19T21:37:37+0000: Finished ministack of size (18, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:37:38+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:09,  1.55it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:01<00:01,  5.39it/s]
# Processing Rasters:  40%|█████████▌              | 6/15 [00:01<00:01,  4.73it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:01<00:01,  5.68it/s]
# Processing Rasters:  67%|███████████████▎       | 10/15 [00:02<00:01,  4.99it/s]
# Processing Rasters:  73%|████████████████▊      | 11/15 [00:02<00:00,  5.00it/s]
# Processing Rasters:  87%|███████████████████▉   | 13/15 [00:02<00:00,  6.53it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:02<00:00,  5.30it/s]
# [INFO|single|L384] 2025-08-19T21:37:41+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:04<00:33,  4.74s/it]
#  25%|███████████▎                                 | 2/8 [00:09<00:26,  4.49s/it]
#  38%|████████████████▉                            | 3/8 [00:13<00:22,  4.59s/it]
#  50%|██████████████████████▌                      | 4/8 [00:18<00:17,  4.46s/it]
#  62%|████████████████████████████▏                | 5/8 [00:22<00:13,  4.45s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:26<00:08,  4.40s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:29<00:03,  3.89s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:32<00:00,  4.09s/it]
# [INFO|single|L395] 2025-08-19T21:38:13+0000: Repacking CRLB files for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:04,  3.16it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  8.65it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:00<00:00, 10.65it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:01<00:00, 12.47it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L114] 2025-08-19T21:38:15+0000: Processing 19 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20240614_20241211
# [INFO|single|L89] 2025-08-19T21:38:15+0000: VRTStack(19 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20240614_20241211.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)) to [datetime.datetime(2024, 12, 11, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:38:17+0000: Processing 15 SLCs + 4 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:38:17+0000: Total stack size (in pixels): (19, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:45:30+0000: Waiting to write 35 blocks of data.
# [INFO|single|L378] 2025-08-19T21:45:30+0000: Finished ministack of size (19, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:45:30+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:08,  1.72it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  5.85it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:01<00:00,  6.36it/s]
# Processing Rasters:  67%|███████████████▎       | 10/15 [00:01<00:00,  6.71it/s]
# Processing Rasters:  73%|████████████████▊      | 11/15 [00:01<00:00,  6.06it/s]
# Processing Rasters:  87%|███████████████████▉   | 13/15 [00:02<00:00,  5.53it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:02<00:00,  6.09it/s]
# [INFO|single|L384] 2025-08-19T21:45:33+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:04<00:33,  4.79s/it]
#  25%|███████████▎                                 | 2/8 [00:09<00:26,  4.49s/it]
#  38%|████████████████▉                            | 3/8 [00:13<00:23,  4.62s/it]
#  50%|██████████████████████▌                      | 4/8 [00:18<00:17,  4.46s/it]
#  62%|████████████████████████████▏                | 5/8 [00:22<00:13,  4.41s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:26<00:08,  4.36s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:29<00:03,  3.86s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:32<00:00,  4.04s/it]
# [INFO|single|L395] 2025-08-19T21:46:05+0000: Repacking CRLB files for more compression
#
# Processing Rasters:   0%|                                | 0/15 [00:00<?, ?it/s]
# Processing Rasters:   7%|█▌                      | 1/15 [00:00<00:04,  3.08it/s]
# Processing Rasters:  33%|████████                | 5/15 [00:00<00:01,  8.69it/s]
# Processing Rasters:  60%|██████████████▍         | 9/15 [00:00<00:00, 10.35it/s]
# Processing Rasters: 100%|███████████████████████| 15/15 [00:01<00:00, 11.57it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L114] 2025-08-19T21:46:06+0000: Processing 6 SLCs. Output folder: /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20241223_20241223
# [INFO|single|L89] 2025-08-19T21:46:06+0000: VRTStack(6 bands, outfile=/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/20241223_20241223.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)) to [datetime.datetime(2024, 12, 23, 0, 0)]
# [INFO|single|L108] 2025-08-19T21:46:09+0000: Processing 1 SLCs + 5 compressed SLCs.
# [INFO|single|L113] 2025-08-19T21:46:09+0000: Total stack size (in pixels): (6, 3500, 12400)
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d[INFO|single|L376] 2025-08-19T21:48:07+0000: Waiting to write 7 blocks of data.
# [INFO|single|L378] 2025-08-19T21:48:07+0000: Finished ministack of size (6, 3500, 12400).
# [INFO|single|L381] 2025-08-19T21:48:07+0000: Repacking phase linking outputs for more compression
#
# Processing Rasters:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Processing Rasters: 100%|█████████████████████████| 1/1 [00:00<00:00,  3.89it/s]
# [INFO|single|L384] 2025-08-19T21:48:07+0000: Creating similarity raster on outputs
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
#  12%|█████▋                                       | 1/8 [00:02<00:15,  2.28s/it]
#  25%|███████████▎                                 | 2/8 [00:04<00:13,  2.26s/it]
#  38%|████████████████▉                            | 3/8 [00:06<00:11,  2.26s/it]
#  50%|██████████████████████▌                      | 4/8 [00:09<00:09,  2.26s/it]
#  62%|████████████████████████████▏                | 5/8 [00:11<00:07,  2.40s/it]
#  75%|█████████████████████████████████▊           | 6/8 [00:13<00:04,  2.35s/it]
#  88%|███████████████████████████████████████▍     | 7/8 [00:15<00:02,  2.24s/it]
# 100%|█████████████████████████████████████████████| 8/8 [00:18<00:00,  2.25s/it]
# [INFO|single|L395] 2025-08-19T21:48:25+0000: Repacking CRLB files for more compression
#
# Processing Rasters: 100%|█████████████████████████| 1/1 [00:00<00:00, 10.09it/s]
# Phase linking (/home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-d
# [INFO|sequential|L258] 2025-08-19T21:48:26+0000: Averaging 6 files into /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/temporal_coherence_average_20220108_20241223.tif
# [INFO|sequential|L258] 2025-08-19T21:48:26+0000: Averaging 6 files into /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/phase_linking/linked_phase/shp_counts_average_20220108_20241223.tif
# 100%|█████████████████████████████████████████████| 8/8 [00:17<00:00,  2.21s/it]
# [INFO|wrapped_phase|L258] 2025-08-19T21:48:44+0000: wrapped_phase complete
# [INFO|wrapped_phase|L286] 2025-08-19T21:48:44+0000: Creating virtual interferograms from 76 files
# [INFO|_log|L102] 2025-08-19T21:48:45+0000: Total elapsed time for dolphin.workflows.wrapped_phase.run : 43.14 minutes (2588.60 seconds)
# [INFO|stitching_bursts|L108] 2025-08-19T21:48:45+0000: Stitching interferograms by date.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 2, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 2, 13, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 20, 0, 0), datetime.datetime(2022, 2, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 20, 0, 0), datetime.datetime(2022, 2, 13, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 1, 20, 0, 0), datetime.datetime(2022, 2, 25, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 1, 0, 0), datetime.datetime(2022, 2, 13, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 1, 0, 0), datetime.datetime(2022, 2, 25, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 1, 0, 0), datetime.datetime(2022, 3, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 13, 0, 0), datetime.datetime(2022, 2, 25, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 13, 0, 0), datetime.datetime(2022, 3, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 13, 0, 0), datetime.datetime(2022, 3, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 25, 0, 0), datetime.datetime(2022, 3, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 25, 0, 0), datetime.datetime(2022, 3, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 2, 25, 0, 0), datetime.datetime(2022, 4, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 9, 0, 0), datetime.datetime(2022, 3, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 9, 0, 0), datetime.datetime(2022, 4, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 9, 0, 0), datetime.datetime(2022, 4, 26, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 21, 0, 0), datetime.datetime(2022, 4, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 21, 0, 0), datetime.datetime(2022, 4, 26, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 3, 21, 0, 0), datetime.datetime(2022, 5, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 2, 0, 0), datetime.datetime(2022, 4, 26, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 2, 0, 0), datetime.datetime(2022, 5, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 2, 0, 0), datetime.datetime(2022, 6, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 26, 0, 0), datetime.datetime(2022, 5, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 26, 0, 0), datetime.datetime(2022, 6, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 4, 26, 0, 0), datetime.datetime(2022, 8, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 5, 8, 0, 0), datetime.datetime(2022, 6, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 5, 8, 0, 0), datetime.datetime(2022, 8, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 5, 8, 0, 0), datetime.datetime(2022, 9, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 6, 1, 0, 0), datetime.datetime(2022, 8, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 6, 1, 0, 0), datetime.datetime(2022, 9, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 6, 1, 0, 0), datetime.datetime(2022, 9, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 8, 12, 0, 0), datetime.datetime(2022, 9, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 8, 12, 0, 0), datetime.datetime(2022, 9, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 8, 12, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 5, 0, 0), datetime.datetime(2022, 9, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 5, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 5, 0, 0), datetime.datetime(2022, 10, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 17, 0, 0), datetime.datetime(2022, 9, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 17, 0, 0), datetime.datetime(2022, 10, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 17, 0, 0), datetime.datetime(2022, 10, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 29, 0, 0), datetime.datetime(2022, 10, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 29, 0, 0), datetime.datetime(2022, 10, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 9, 29, 0, 0), datetime.datetime(2022, 11, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 11, 0, 0), datetime.datetime(2022, 10, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 11, 0, 0), datetime.datetime(2022, 11, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 11, 0, 0), datetime.datetime(2022, 11, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 23, 0, 0), datetime.datetime(2022, 11, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 23, 0, 0), datetime.datetime(2022, 11, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 10, 23, 0, 0), datetime.datetime(2022, 11, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 4, 0, 0), datetime.datetime(2022, 11, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 4, 0, 0), datetime.datetime(2022, 11, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 4, 0, 0), datetime.datetime(2022, 12, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 16, 0, 0), datetime.datetime(2022, 11, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 16, 0, 0), datetime.datetime(2022, 12, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 16, 0, 0), datetime.datetime(2022, 12, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 28, 0, 0), datetime.datetime(2022, 12, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 28, 0, 0), datetime.datetime(2022, 12, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 11, 28, 0, 0), datetime.datetime(2023, 1, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 10, 0, 0), datetime.datetime(2022, 12, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 10, 0, 0), datetime.datetime(2023, 1, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 10, 0, 0), datetime.datetime(2023, 1, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 22, 0, 0), datetime.datetime(2023, 1, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 22, 0, 0), datetime.datetime(2023, 1, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2022, 12, 22, 0, 0), datetime.datetime(2023, 1, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 3, 0, 0), datetime.datetime(2023, 1, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 3, 0, 0), datetime.datetime(2023, 1, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 3, 0, 0), datetime.datetime(2023, 2, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 15, 0, 0), datetime.datetime(2023, 1, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 15, 0, 0), datetime.datetime(2023, 2, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 15, 0, 0), datetime.datetime(2023, 2, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 27, 0, 0), datetime.datetime(2023, 2, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 27, 0, 0), datetime.datetime(2023, 2, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 1, 27, 0, 0), datetime.datetime(2023, 3, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 8, 0, 0), datetime.datetime(2023, 2, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 8, 0, 0), datetime.datetime(2023, 3, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 8, 0, 0), datetime.datetime(2023, 3, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 20, 0, 0), datetime.datetime(2023, 3, 4, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 20, 0, 0), datetime.datetime(2023, 3, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 2, 20, 0, 0), datetime.datetime(2023, 3, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 4, 0, 0), datetime.datetime(2023, 3, 16, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 4, 0, 0), datetime.datetime(2023, 3, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 4, 0, 0), datetime.datetime(2023, 4, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 16, 0, 0), datetime.datetime(2023, 3, 28, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 16, 0, 0), datetime.datetime(2023, 4, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 16, 0, 0), datetime.datetime(2023, 4, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 28, 0, 0), datetime.datetime(2023, 4, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 28, 0, 0), datetime.datetime(2023, 4, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 3, 28, 0, 0), datetime.datetime(2023, 5, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 9, 0, 0), datetime.datetime(2023, 4, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 9, 0, 0), datetime.datetime(2023, 5, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 9, 0, 0), datetime.datetime(2023, 5, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 21, 0, 0), datetime.datetime(2023, 5, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 21, 0, 0), datetime.datetime(2023, 5, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 4, 21, 0, 0), datetime.datetime(2023, 6, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 3, 0, 0), datetime.datetime(2023, 5, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 3, 0, 0), datetime.datetime(2023, 6, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 3, 0, 0), datetime.datetime(2023, 8, 19, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 15, 0, 0), datetime.datetime(2023, 6, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 15, 0, 0), datetime.datetime(2023, 8, 19, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 5, 15, 0, 0), datetime.datetime(2023, 8, 31, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 6, 20, 0, 0), datetime.datetime(2023, 8, 19, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 6, 20, 0, 0), datetime.datetime(2023, 8, 31, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 6, 20, 0, 0), datetime.datetime(2023, 9, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 19, 0, 0), datetime.datetime(2023, 8, 31, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 19, 0, 0), datetime.datetime(2023, 9, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 19, 0, 0), datetime.datetime(2023, 9, 24, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 31, 0, 0), datetime.datetime(2023, 9, 12, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 31, 0, 0), datetime.datetime(2023, 9, 24, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 8, 31, 0, 0), datetime.datetime(2023, 10, 6, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 12, 0, 0), datetime.datetime(2023, 9, 24, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 12, 0, 0), datetime.datetime(2023, 10, 6, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 12, 0, 0), datetime.datetime(2023, 10, 18, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 24, 0, 0), datetime.datetime(2023, 10, 6, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 24, 0, 0), datetime.datetime(2023, 10, 18, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 9, 24, 0, 0), datetime.datetime(2023, 10, 30, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 6, 0, 0), datetime.datetime(2023, 10, 18, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 6, 0, 0), datetime.datetime(2023, 10, 30, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 6, 0, 0), datetime.datetime(2023, 11, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 18, 0, 0), datetime.datetime(2023, 10, 30, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 18, 0, 0), datetime.datetime(2023, 11, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 18, 0, 0), datetime.datetime(2023, 11, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 30, 0, 0), datetime.datetime(2023, 11, 11, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 30, 0, 0), datetime.datetime(2023, 11, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 10, 30, 0, 0), datetime.datetime(2023, 12, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 11, 0, 0), datetime.datetime(2023, 11, 23, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 11, 0, 0), datetime.datetime(2023, 12, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 11, 0, 0), datetime.datetime(2023, 12, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 23, 0, 0), datetime.datetime(2023, 12, 5, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 23, 0, 0), datetime.datetime(2023, 12, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 11, 23, 0, 0), datetime.datetime(2023, 12, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 5, 0, 0), datetime.datetime(2023, 12, 17, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 5, 0, 0), datetime.datetime(2023, 12, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 5, 0, 0), datetime.datetime(2024, 1, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 17, 0, 0), datetime.datetime(2023, 12, 29, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 17, 0, 0), datetime.datetime(2024, 1, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 17, 0, 0), datetime.datetime(2024, 1, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 29, 0, 0), datetime.datetime(2024, 1, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 29, 0, 0), datetime.datetime(2024, 1, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2023, 12, 29, 0, 0), datetime.datetime(2024, 2, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 10, 0, 0), datetime.datetime(2024, 1, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 10, 0, 0), datetime.datetime(2024, 2, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 10, 0, 0), datetime.datetime(2024, 2, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 22, 0, 0), datetime.datetime(2024, 2, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 22, 0, 0), datetime.datetime(2024, 2, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 1, 22, 0, 0), datetime.datetime(2024, 2, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 3, 0, 0), datetime.datetime(2024, 2, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 3, 0, 0), datetime.datetime(2024, 2, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 3, 0, 0), datetime.datetime(2024, 3, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 15, 0, 0), datetime.datetime(2024, 2, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 15, 0, 0), datetime.datetime(2024, 3, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 15, 0, 0), datetime.datetime(2024, 3, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 27, 0, 0), datetime.datetime(2024, 3, 10, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 27, 0, 0), datetime.datetime(2024, 3, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 2, 27, 0, 0), datetime.datetime(2024, 4, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 10, 0, 0), datetime.datetime(2024, 3, 22, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 10, 0, 0), datetime.datetime(2024, 4, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 10, 0, 0), datetime.datetime(2024, 4, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 22, 0, 0), datetime.datetime(2024, 4, 3, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 22, 0, 0), datetime.datetime(2024, 4, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 3, 22, 0, 0), datetime.datetime(2024, 4, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 3, 0, 0), datetime.datetime(2024, 4, 15, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 3, 0, 0), datetime.datetime(2024, 4, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 3, 0, 0), datetime.datetime(2024, 5, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 15, 0, 0), datetime.datetime(2024, 4, 27, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 15, 0, 0), datetime.datetime(2024, 5, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 15, 0, 0), datetime.datetime(2024, 5, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 27, 0, 0), datetime.datetime(2024, 5, 9, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 27, 0, 0), datetime.datetime(2024, 5, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 4, 27, 0, 0), datetime.datetime(2024, 6, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 9, 0, 0), datetime.datetime(2024, 5, 21, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 9, 0, 0), datetime.datetime(2024, 6, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 9, 0, 0), datetime.datetime(2024, 6, 14, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 21, 0, 0), datetime.datetime(2024, 6, 2, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 21, 0, 0), datetime.datetime(2024, 6, 14, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 5, 21, 0, 0), datetime.datetime(2024, 7, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 2, 0, 0), datetime.datetime(2024, 6, 14, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 2, 0, 0), datetime.datetime(2024, 7, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 2, 0, 0), datetime.datetime(2024, 7, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 14, 0, 0), datetime.datetime(2024, 7, 8, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 14, 0, 0), datetime.datetime(2024, 7, 20, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 6, 14, 0, 0), datetime.datetime(2024, 8, 1, 0, 0)): Stitching 1 images.
# [INFO|stitching|L112] 2025-08-19T21:48:45+0000: (datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 20, 0, 0)): Stitching 1 images.
# ...
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu.conncomp.bg61tff9.u4 as 4-byte unsigned ints
# Maximum flow on network: 1
# Total solution cost: 34761421
# Integrating phase
# Writing output to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu.unw.mms55i68.f4
# Program snaphu done
# Elapsed processor time:   0:00:35.68
# Elapsed wall clock time:  0:00:36
# [INFO|_unwrap|L477] 2025-08-20T00:12:56+0000: Transferring ambiguity numbers from filtered/interpolated ifg /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif
#
# snaphu v2.0.7
# 12 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu-regrow-conncomps.config.67xmzsd0.txt (12 lines total)
# Reading unwrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu.unw.6jmxc4x9.f4
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu.corr.fo7vwmss.f4
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241117_20241223.int/snaphu.conncomp.i9othn86.u4 as 4-byte unsigned ints
# Program snaphu done
# Elapsed processor time:   0:00:00.58
# Elapsed wall clock time:  0:00:01
# [INFO|_unwrap|L513] 2025-08-20T00:12:57+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif file
# [INFO|_unwrap|L517] 2025-08-20T00:12:57+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/20241117_20241223.unw.conncomp.tif file
# [INFO|_unwrap|L379] 2025-08-20T00:12:57+0000: Masking pixels with correlation below 0.25
# [INFO|_unwrap|L384] 2025-08-20T00:12:57+0000: Masking pixels with similarity below 0.3
# [INFO|_unwrap|L388] 2025-08-20T00:12:57+0000: Interpolating /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/interferograms/20241129_20241211.int.tif -> /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/20241129_20241211.interp.int.tif
# [INFO|_unwrap|L406] 2025-08-20T00:12:58+0000: Writing interpolated output to /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/20241129_20241211.interp.int.tif
#
# snaphu v2.0.7
# 22 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.config.qedj66fd.txt (22 lines total)
# Reading wrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.igram.lzdz3pje.c8
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.corr.fxyz4_0u.f4
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.conncomp.i1ohp9ru.u4 as 4-byte unsigned ints
# Maximum flow on network: 1
# Total solution cost: 55782215
# Integrating phase
# Writing output to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.unw.7xw495_9.f4
# Program snaphu done
# Elapsed processor time:   0:00:35.21
# Elapsed wall clock time:  0:00:35
# [INFO|_unwrap|L477] 2025-08-20T00:13:34+0000: Transferring ambiguity numbers from filtered/interpolated ifg /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif
#
# snaphu v2.0.7
# 12 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu-regrow-conncomps.config.fkfdnydw.txt (12 lines total)
# Reading unwrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.unw.9gtf1i8h.f4
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.corr.tknoypp_.f4
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241211.int/snaphu.conncomp.7smunfcu.u4 as 4-byte unsigned ints
# Program snaphu done
# Elapsed processor time:   0:00:00.60
# Elapsed wall clock time:  0:00:01
# [INFO|_unwrap|L513] 2025-08-20T00:13:35+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif file
# [INFO|_unwrap|L517] 2025-08-20T00:13:35+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/20241129_20241211.unw.conncomp.tif file
# [INFO|_unwrap|L379] 2025-08-20T00:13:35+0000: Masking pixels with correlation below 0.25
# [INFO|_unwrap|L384] 2025-08-20T00:13:35+0000: Masking pixels with similarity below 0.3
# [INFO|_unwrap|L388] 2025-08-20T00:13:35+0000: Interpolating /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/interferograms/20241129_20241223.int.tif -> /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/20241129_20241223.interp.int.tif
# [INFO|_unwrap|L406] 2025-08-20T00:13:37+0000: Writing interpolated output to /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/20241129_20241223.interp.int.tif
#
# snaphu v2.0.7
# 22 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.config.89g40gy3.txt (22 lines total)
# Reading wrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.igram.r2q2nkwa.c8
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.corr.7zj82s7n.f4
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.conncomp.8czer_sf.u4 as 4-byte unsigned ints
# Maximum flow on network: 1
# Total solution cost: 36550729
# Integrating phase
# Writing output to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.unw.hqks6jsw.f4
# Program snaphu done
# Elapsed processor time:   0:00:34.46
# Elapsed wall clock time:  0:00:35
# [INFO|_unwrap|L477] 2025-08-20T00:14:12+0000: Transferring ambiguity numbers from filtered/interpolated ifg /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif
#
# snaphu v2.0.7
# 12 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu-regrow-conncomps.config.n4f10f2v.txt (12 lines total)
# Reading unwrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.unw.k5a1tkgn.f4
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.corr.wlhb11ej.f4
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241129_20241223.int/snaphu.conncomp.fu16oxh5.u4 as 4-byte unsigned ints
# Program snaphu done
# Elapsed processor time:   0:00:00.58
# Elapsed wall clock time:  0:00:00
# [INFO|_unwrap|L513] 2025-08-20T00:14:13+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif file
# [INFO|_unwrap|L517] 2025-08-20T00:14:13+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/20241129_20241223.unw.conncomp.tif file
# [INFO|_unwrap|L379] 2025-08-20T00:14:13+0000: Masking pixels with correlation below 0.25
# [INFO|_unwrap|L384] 2025-08-20T00:14:13+0000: Masking pixels with similarity below 0.3
# [INFO|_unwrap|L388] 2025-08-20T00:14:13+0000: Interpolating /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/interferograms/20241211_20241223.int.tif -> /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/20241211_20241223.interp.int.tif
# [INFO|_unwrap|L406] 2025-08-20T00:14:15+0000: Writing interpolated output to /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/20241211_20241223.interp.int.tif
#
# snaphu v2.0.7
# 22 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.config.mrp61_3s.txt (22 lines total)
# Reading wrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.igram.wzge5t1q.c8
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.corr.lh2d44of.f4
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.conncomp.5qe8qqlt.u4 as 4-byte unsigned ints
# Maximum flow on network: 1
# Total solution cost: 38268082
# Integrating phase
# Writing output to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.unw.jixulp1o.f4
# Program snaphu done
# Elapsed processor time:   0:00:35.47
# Elapsed wall clock time:  0:00:36
# [INFO|_unwrap|L477] 2025-08-20T00:14:51+0000: Transferring ambiguity numbers from filtered/interpolated ifg /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif
#
# snaphu v2.0.7
# 12 parameters input from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu-regrow-conncomps.config.hr10kjx2.txt (12 lines total)
# Reading unwrapped phase from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.unw._wj65lsk.f4
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.corr.drvpwssv.f4
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/scratch/scratch-20241211_20241223.int/snaphu.conncomp.iu130_ip.u4 as 4-byte unsigned ints
# Program snaphu done
# Elapsed processor time:   0:00:00.58
# Elapsed wall clock time:  0:00:00
# [INFO|_unwrap|L513] 2025-08-20T00:14:51+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.interp.unw.tif file
# [INFO|_unwrap|L517] 2025-08-20T00:14:52+0000: Setting nodata values of /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/unwrapped/20241211_20241223.unw.conncomp.tif file
# 222it [00:00, 301046.07it/s]
# [INFO|unwrapping|L98] 2025-08-20T00:14:52+0000: Creating overviews for unwrapped images
# 100%|█████████████████████████████████████████| 222/222 [00:03<00:00, 64.25it/s]
# 100%|████████████████████████████████████████| 222/222 [00:00<00:00, 385.32it/s]
# [INFO|unwrapping|L103] 2025-08-20T00:14:56+0000: unwrapping complete
# [INFO|_log|L102] 2025-08-20T00:14:56+0000: Total elapsed time for dolphin.workflows.unwrapping.run : 144.24 minutes (8654.46 seconds)
# [INFO|timeseries|L153] 2025-08-20T00:14:56+0000: Selecting a reference point for unwrapped interferograms
# [INFO|timeseries|L1313] 2025-08-20T00:14:56+0000: Selecting reference point
# [INFO|timeseries|L1395] 2025-08-20T00:14:56+0000: Creating intersection of connected components
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 12.00it/s]
# [INFO|timeseries|L1415] 2025-08-20T00:14:59+0000: Found 143 connected components in intersection
# [INFO|timeseries|L1363] 2025-08-20T00:14:59+0000: Saving ReferencePoint(row=1111, col=379) to /home/jovyan/Sara_work/2025-isceplus/5.3_Intro_to_Dolphin/isce2-dolphin/timeseries/reference_point.txt
# [INFO|timeseries|L207] 2025-08-20T00:14:59+0000: Inverting network of 222 unwrapped ifgs
# [INFO|timeseries|L1060] 2025-08-20T00:14:59+0000: Inverting network using L1-norm minimization
# [INFO|timeseries|L1095] 2025-08-20T00:15:00+0000: Using unweighted unw inversion
# 100%|███████████████████████████████████████████| 35/35 [02:10<00:00,  3.72s/it]
# [INFO|timeseries|L1197] 2025-08-20T00:17:11+0000: Completed invert_unw_network
# [INFO|timeseries|L232] 2025-08-20T00:17:11+0000: Creating overviews for timeseries images
# 100%|███████████████████████████████████████████| 75/75 [00:01<00:00, 46.13it/s]
# [INFO|timeseries|L236] 2025-08-20T00:17:13+0000: Estimating phase velocity
# [INFO|timeseries|L828] 2025-08-20T00:17:13+0000: Using unweighted fit for velocity.
# [INFO|timeseries|L834] 2025-08-20T00:17:13+0000: Reading phase reference pixel ReferencePoint(row=1111, col=379)
# 100%|███████████████████████████████████████████| 35/35 [00:01<00:00, 23.87it/s]
# [INFO|timeseries|L877] 2025-08-20T00:17:15+0000: Creating overviews for velocity image
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 23.76it/s]
# [INFO|timeseries|L892] 2025-08-20T00:17:15+0000: Completed create_velocity
# [INFO|displacement|L333] 2025-08-20T00:17:15+0000: Maximum memory usage: 24.59 GB
# [INFO|displacement|L334] 2025-08-20T00:17:15+0000: Config file dolphin version: 0.41.0
# [INFO|displacement|L335] 2025-08-20T00:17:15+0000: Current running dolphin version: 0.41.0
# [INFO|_log|L102] 2025-08-20T00:17:15+0000: Total elapsed time for dolphin.workflows.displacement.run : 191.65 minutes (11498.99 seconds)

# %% [markdown]
# The outputs of the workflow are displacement timeseries and velocity map. There are byproducts includig the inversion residuals, a conected component intersection from all unwrapped interferograms, PS mask, temporal coherence, shp counts, phase similarity for all ministacks and crlb. You can also find the amplitude dispersion used for finding PS pixels.

# %% [markdown]
# #### Velocity map
# ![Velocity_map](docs/velocity_map.png)

# %% [markdown]
# # 3. Other dolphin commands
# 1. You can run snaphu on all interferograms in a directory and unwrap them with the `unwrap` subcommand.
# 2. You can invert the unwrapped interferograms, estimate timeseries and phase velocity with the `timeseries` subcommand
# 3. You can filter a list of unwrapped interferogram files using a long-wavelength filter with the `filter` subcommnd and generate short wavelength products

# %%
# dolphin unwrap --help
# dolphin timeseries --help
# dolphin filter --help
